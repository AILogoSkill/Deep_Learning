# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import utils
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
from google.colab import files
# %matplotlib inline

# %%
# !unzip -q archive.zip
# Out:
# replace annotations.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
os.listdir(path='/content/')
# Out:
# ['.config',
#  'archive',
#  'annotations.csv',
#  'images',
#  'Trafic_sign.hdf5',
#  'archive.zip',
#  '.ipynb_checkpoints',
#  'sample_data']

# %%
# importing cv2 
import cv2 as cv

# %%
import pandas as pd
df=pd.read_csv('annotations.csv')
df.head()
# Out:
#       file_name  width  height  x1  y1   x2   y2  category
# 0  000_0001.png    134     128  19   7  120  117         0
# 1  000_0002.png    165     151  23  12  149  138         0
# 2  000_0003.png    128     122  22  14  116  105         0
# 3  000_0010.png     80      73  14   8   67   63         0
# 4  000_0011.png    186     174  36  15  155  157         0

# %%
df['category'] = df['category'].astype('str')

# %%
plt.figure(figsize=(20,20))
df['category'].value_counts().plot(kind='bar')
plt.show()

# %%
path='images/000_0001.png'
img=plt.imread(path)
plt.imshow(img)

# %%
path='/content'

# %%
import IPython.display as display
from PIL import Image
from PIL.ImageDraw import Draw

for index, row in df.sample(frac=1)[:5].iterrows():
    image = Image.open(os.path.join(path, 'images', row.file_name))
    draw = Draw(image)
    draw.rectangle([row.x1, row.y1, row.x2, row.y2], outline='#00FF00', width=3)
    display.display(image)
    print('category:', row.category)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=48x52 at 0x7F7BAD36D400>
# category: 3
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=154x139 at 0x7F7BAD36D0A0>
# category: 28
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=132x130 at 0x7F7BB88FA550>
# category: 55
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=170x158 at 0x7F7BAD36D070>
# category: 56
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=210x206 at 0x7F7BAD36DEB0>
# category: 28

# %%
img.shape
# Out:
# (128, 134, 3)

# %%
from keras.applications.mobilenet_v2 import  preprocess_input
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
            
            preprocessing_function=preprocess_input,
            validation_split=0.1,
            featurewise_center=False,
            featurewise_std_normalization=False,
            rotation_range=15,
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True
            
            )

# %%
        # Train generator
train_generator = datagen.flow_from_dataframe(
            dataframe=df,
            directory="images",
            x_col="file_name",
            y_col="category",
            has_ext=False,
            subset="training",
            batch_size=16,
            seed=42,
            shuffle=True,
            class_mode="categorical",
            target_size=(224,244))
        print('Train generator created')
# Out:
# Found 5548 validated image filenames belonging to 58 classes.
# Train generator created

# %%
classes=list(train_generator.class_indices.keys())
plt.figure(figsize=(20,20))
for X_batch, y_batch in train_generator:
    # create a grid of 3x3 images
    for i in range(0,8):
        plt.subplot(2,4,i+1)
        plt.imshow(X_batch[i])
        plt.title(classes[np.where(y_batch[i]==1)[0][0]])
    # show the plot
    plt.show()
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.applications.mobilenet_v2 import  preprocess_input
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
            
            preprocessing_function=preprocess_input,
            validation_split=0.1,
            
            )
val_generator = datagen.flow_from_dataframe(
            dataframe=df,
            directory='images',
            x_col="file_name",
            y_col="category",
            has_ext=False,
            subset="validation",
            batch_size=16,
            seed=42,
            shuffle=False,
            class_mode="categorical",
            target_size=(224,224))
# Out:
# Found 616 validated image filenames belonging to 58 classes.

# %%
classes=list(train_generator.class_indices.keys())
plt.figure(figsize=(20,20))
for X_batch, y_batch in val_generator:
    # create a grid of 3x3 images
    for i in range(0,8):
        plt.subplot(2,4,i+1)
        plt.imshow(X_batch[i])
        plt.title(classes[np.where(y_batch[i]==1)[0][0]])
    # show the plot
    plt.show()
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
len(classes)
# Out:
# 58

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense ,Flatten ,Conv2D ,MaxPooling2D ,Dropout ,BatchNormalization
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.callbacks import EarlyStopping ,ReduceLROnPlateau ,ModelCheckpoint

# %%
optimizer=Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.99)
EarlyStop=EarlyStopping(patience=10,restore_best_weights=True)
Reduce_LR=ReduceLROnPlateau(monitor='val_accuracy',verbose=2,factor=0.5,min_lr=0.00001)
model_check=ModelCheckpoint('Trafic_sign.hdf5',monitor='val_loss',verbose=1,save_best_only=True)
callback=[EarlyStop , Reduce_LR,model_check]
from keras.applications.mobilenet_v2 import MobileNetV2
mb=MobileNetV2(include_top=False,input_shape=(224,224,3),weights='imagenet')
mb.trainable=False

# %%
model = Sequential()
model.add(mb)
model.add(Flatten())
model.add(Dense(units = 512 , activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(units = 1024 , activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(units = 512 , activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(units = 58 , activation = 'softmax'))

# %%
model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics=["accuracy"])
history=model.fit(train_generator,validation_data=val_generator,epochs=100,batch_size=16,
                  steps_per_epoch=len(train_generator)//16,validation_steps=len(val_generator)//16,
                  callbacks=callback, verbose=1)
# Out:
# Epoch 1/100
# 21/21 [==============================] - ETA: 0s - loss: 3.7147 - accuracy: 0.2649
# Epoch 1: val_loss improved from inf to 16.30762, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 38s 2s/step - loss: 3.7147 - accuracy: 0.2649 - val_loss: 16.3076 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/100
# 21/21 [==============================] - ETA: 0s - loss: 2.3372 - accuracy: 0.4337
# Epoch 2: val_loss improved from 16.30762 to 7.99605, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 41s 2s/step - loss: 2.3372 - accuracy: 0.4337 - val_loss: 7.9960 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 3/100
# 21/21 [==============================] - ETA: 0s - loss: 1.9480 - accuracy: 0.4821
# Epoch 3: val_loss did not improve from 7.99605
# 21/21 [==============================] - 33s 1s/step - loss: 1.9480 - accuracy: 0.4821 - val_loss: 8.2614 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 4/100
# 21/21 [==============================] - ETA: 0s - loss: 1.6825 - accuracy: 0.5446
# Epoch 4: val_loss improved from 7.99605 to 3.60496, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 30s 1s/step - loss: 1.6825 - accuracy: 0.5446 - val_loss: 3.6050 - val_accuracy: 0.1562 - lr: 0.0010
# Epoch 5/100
# 21/21 [==============================] - ETA: 0s - loss: 1.5733 - accuracy: 0.5833
# Epoch 5: val_loss did not improve from 3.60496
# 21/21 [==============================] - 29s 1s/step - loss: 1.5733 - accuracy: 0.5833 - val_loss: 4.5267 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 6/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3957 - accuracy: 0.6310
# Epoch 6: val_loss improved from 3.60496 to 1.01715, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 31s 1s/step - loss: 1.3957 - accuracy: 0.6310 - val_loss: 1.0172 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 7/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3213 - accuracy: 0.6339
# Epoch 7: val_loss improved from 1.01715 to 0.96674, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 31s 1s/step - loss: 1.3213 - accuracy: 0.6339 - val_loss: 0.9667 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 8/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0848 - accuracy: 0.6518
# Epoch 8: val_loss improved from 0.96674 to 0.35495, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 30s 1s/step - loss: 1.0848 - accuracy: 0.6518 - val_loss: 0.3550 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 9/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0678 - accuracy: 0.6845
# Epoch 9: val_loss did not improve from 0.35495
# 21/21 [==============================] - 30s 1s/step - loss: 1.0678 - accuracy: 0.6845 - val_loss: 1.5440 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 10/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8030 - accuracy: 0.7711
# Epoch 10: val_loss did not improve from 0.35495
# 21/21 [==============================] - 28s 1s/step - loss: 0.8030 - accuracy: 0.7711 - val_loss: 3.1412 - val_accuracy: 0.3125 - lr: 0.0010
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0461 - accuracy: 0.7024
# Epoch 11: val_loss did not improve from 0.35495
# 21/21 [==============================] - 29s 1s/step - loss: 1.0461 - accuracy: 0.7024 - val_loss: 0.6197 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 12/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.7887
# Epoch 12: val_loss did not improve from 0.35495
# 21/21 [==============================] - 38s 2s/step - loss: 0.6935 - accuracy: 0.7887 - val_loss: 0.7845 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 13/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9925 - accuracy: 0.7202
# Epoch 13: val_loss improved from 0.35495 to 0.24990, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 32s 2s/step - loss: 0.9925 - accuracy: 0.7202 - val_loss: 0.2499 - val_accuracy: 0.9688 - lr: 0.0010
# Epoch 14/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9388 - accuracy: 0.7500
# Epoch 14: val_loss improved from 0.24990 to 0.20063, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 30s 1s/step - loss: 0.9388 - accuracy: 0.7500 - val_loss: 0.2006 - val_accuracy: 0.9688 - lr: 0.0010
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8003 - accuracy: 0.7827
# Epoch 15: val_loss did not improve from 0.20063
# 21/21 [==============================] - 32s 1s/step - loss: 0.8003 - accuracy: 0.7827 - val_loss: 0.6370 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 16/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8046 - accuracy: 0.7619
# Epoch 16: val_loss did not improve from 0.20063
# 21/21 [==============================] - 29s 1s/step - loss: 0.8046 - accuracy: 0.7619 - val_loss: 0.3232 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 17/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9473 - accuracy: 0.7173
# Epoch 17: val_loss did not improve from 0.20063
# 21/21 [==============================] - 29s 1s/step - loss: 0.9473 - accuracy: 0.7173 - val_loss: 1.1048 - val_accuracy: 0.6562 - lr: 0.0010
# Epoch 18/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7347 - accuracy: 0.7917
# Epoch 18: val_loss did not improve from 0.20063
# 21/21 [==============================] - 30s 1s/step - loss: 0.7347 - accuracy: 0.7917 - val_loss: 1.0258 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8248 - accuracy: 0.7649
# Epoch 19: val_loss did not improve from 0.20063
# 21/21 [==============================] - 29s 1s/step - loss: 0.8248 - accuracy: 0.7649 - val_loss: 0.7126 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 20/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8133 - accuracy: 0.7738
# Epoch 20: val_loss did not improve from 0.20063
# 21/21 [==============================] - 28s 1s/step - loss: 0.8133 - accuracy: 0.7738 - val_loss: 0.2925 - val_accuracy: 0.9688 - lr: 0.0010
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.7887
# Epoch 21: val_loss did not improve from 0.20063
# 21/21 [==============================] - 28s 1s/step - loss: 0.7198 - accuracy: 0.7887 - val_loss: 1.7107 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 22/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7291 - accuracy: 0.7589
# Epoch 22: val_loss did not improve from 0.20063
# 21/21 [==============================] - 29s 1s/step - loss: 0.7291 - accuracy: 0.7589 - val_loss: 0.3431 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6536 - accuracy: 0.8185
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 23: val_loss did not improve from 0.20063
# 21/21 [==============================] - 30s 1s/step - loss: 0.6536 - accuracy: 0.8185 - val_loss: 0.2218 - val_accuracy: 0.9375 - lr: 0.0010
# Epoch 24/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.8661
# Epoch 24: val_loss improved from 0.20063 to 0.17980, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 31s 1s/step - loss: 0.4541 - accuracy: 0.8661 - val_loss: 0.1798 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.8661
# Epoch 25: val_loss improved from 0.17980 to 0.14854, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 29s 1s/step - loss: 0.4061 - accuracy: 0.8661 - val_loss: 0.1485 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 26/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4577 - accuracy: 0.8780
# Epoch 26: val_loss did not improve from 0.14854
# 21/21 [==============================] - 28s 1s/step - loss: 0.4577 - accuracy: 0.8780 - val_loss: 0.1791 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 27/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.8423
# Epoch 27: val_loss improved from 0.14854 to 0.11881, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 29s 1s/step - loss: 0.4574 - accuracy: 0.8423 - val_loss: 0.1188 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4568 - accuracy: 0.8690
# Epoch 28: val_loss improved from 0.11881 to 0.06219, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 31s 1s/step - loss: 0.4568 - accuracy: 0.8690 - val_loss: 0.0622 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3635 - accuracy: 0.8899
# Epoch 29: val_loss did not improve from 0.06219
# 21/21 [==============================] - 35s 2s/step - loss: 0.3635 - accuracy: 0.8899 - val_loss: 0.1238 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.8869
# Epoch 30: val_loss did not improve from 0.06219
# 21/21 [==============================] - 29s 1s/step - loss: 0.4098 - accuracy: 0.8869 - val_loss: 0.0877 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 31/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.8423
# Epoch 31: val_loss did not improve from 0.06219
# 21/21 [==============================] - 30s 1s/step - loss: 0.4544 - accuracy: 0.8423 - val_loss: 0.0869 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4354 - accuracy: 0.8810
# Epoch 32: val_loss did not improve from 0.06219
# 21/21 [==============================] - 30s 1s/step - loss: 0.4354 - accuracy: 0.8810 - val_loss: 0.0863 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8780
# Epoch 33: val_loss did not improve from 0.06219
# 21/21 [==============================] - 29s 1s/step - loss: 0.4034 - accuracy: 0.8780 - val_loss: 0.2016 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 34/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.8690
# Epoch 34: val_loss did not improve from 0.06219
# 21/21 [==============================] - 29s 1s/step - loss: 0.4361 - accuracy: 0.8690 - val_loss: 0.1805 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 35/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3995 - accuracy: 0.8750
# Epoch 35: val_loss did not improve from 0.06219
# 21/21 [==============================] - 30s 1s/step - loss: 0.3995 - accuracy: 0.8750 - val_loss: 0.1272 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 36/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3160 - accuracy: 0.8988
# Epoch 36: val_loss did not improve from 0.06219
# 21/21 [==============================] - 29s 1s/step - loss: 0.3160 - accuracy: 0.8988 - val_loss: 0.0634 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 37/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3668 - accuracy: 0.8690
# Epoch 37: val_loss did not improve from 0.06219
# 21/21 [==============================] - 29s 1s/step - loss: 0.3668 - accuracy: 0.8690 - val_loss: 0.1519 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 38/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.9048
# Epoch 38: val_loss improved from 0.06219 to 0.03973, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 31s 1s/step - loss: 0.3293 - accuracy: 0.9048 - val_loss: 0.0397 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 39/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.9048
# Epoch 39: val_loss did not improve from 0.03973
# 21/21 [==============================] - 30s 1s/step - loss: 0.3419 - accuracy: 0.9048 - val_loss: 0.0439 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 40/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9167
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 40: val_loss improved from 0.03973 to 0.03652, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 36s 2s/step - loss: 0.2611 - accuracy: 0.9167 - val_loss: 0.0365 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 41/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.8958
# Epoch 41: val_loss did not improve from 0.03652
# 21/21 [==============================] - 33s 2s/step - loss: 0.3314 - accuracy: 0.8958 - val_loss: 0.0409 - val_accuracy: 0.9688 - lr: 2.5000e-04
# Epoch 42/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9107
# Epoch 42: val_loss improved from 0.03652 to 0.01559, saving model to Trafic_sign.hdf5
# 21/21 [==============================] - 35s 2s/step - loss: 0.2521 - accuracy: 0.9107 - val_loss: 0.0156 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 43/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8988
# Epoch 43: val_loss did not improve from 0.01559
# 21/21 [==============================] - 34s 2s/step - loss: 0.2803 - accuracy: 0.8988 - val_loss: 0.0327 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 44/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9286
# Epoch 44: val_loss did not improve from 0.01559
# 21/21 [==============================] - 33s 2s/step - loss: 0.2426 - accuracy: 0.9286 - val_loss: 0.0290 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 45/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9256
# Epoch 45: val_loss did not improve from 0.01559
# 21/21 [==============================] - 42s 2s/step - loss: 0.2527 - accuracy: 0.9256 - val_loss: 0.0398 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 46/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2556 - accuracy: 0.9167
# Epoch 46: val_loss did not improve from 0.01559
# 21/21 [==============================] - 39s 2s/step - loss: 0.2556 - accuracy: 0.9167 - val_loss: 0.0932 - val_accuracy: 0.9688 - lr: 2.5000e-04
# Epoch 47/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9167
# Epoch 47: val_loss did not improve from 0.01559
# 21/21 [==============================] - 35s 2s/step - loss: 0.1966 - accuracy: 0.9167 - val_loss: 0.0639 - val_accuracy: 0.9688 - lr: 2.5000e-04
# Epoch 48/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9196
# Epoch 48: val_loss did not improve from 0.01559
# 21/21 [==============================] - 30s 1s/step - loss: 0.2261 - accuracy: 0.9196 - val_loss: 0.0283 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 49/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1547 - accuracy: 0.9613
# Epoch 49: val_loss did not improve from 0.01559
# 21/21 [==============================] - 29s 1s/step - loss: 0.1547 - accuracy: 0.9613 - val_loss: 0.0312 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 50/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9613
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 50: val_loss did not improve from 0.01559
# 21/21 [==============================] - 29s 1s/step - loss: 0.1125 - accuracy: 0.9613 - val_loss: 0.0813 - val_accuracy: 0.9688 - lr: 2.5000e-04
# Epoch 51/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9375
# Epoch 51: val_loss did not improve from 0.01559
# 21/21 [==============================] - 29s 1s/step - loss: 0.1843 - accuracy: 0.9375 - val_loss: 0.0693 - val_accuracy: 0.9688 - lr: 1.2500e-04
# Epoch 52/100
# 21/21 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9673
# Epoch 52: val_loss did not improve from 0.01559
# 21/21 [==============================] - 30s 1s/step - loss: 0.1583 - accuracy: 0.9673 - val_loss: 0.0442 - val_accuracy: 0.9688 - lr: 1.2500e-04

# %%
loss,acc=model.evaluate(val_generator)
# Out:
# 39/39 [==============================] - 22s 556ms/step - loss: 1.0837 - accuracy: 0.9042

# %%
#plotting training values
import seaborn as sns
sns.set()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

#accuracy plot
plt.plot(epochs, acc, color='green', label='Training Accuracy')
plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.figure()
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
predictions = model.predict(val_generator)
# Out:
# 39/39 [==============================] - 23s 556ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(val_generator.classes, predictions.argmax(axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       0.79      1.00      0.88        15
#            2       1.00      0.50      0.67         4
#            3       1.00      1.00      1.00        10
#            4       1.00      1.00      1.00        30
#            5       0.79      1.00      0.88        11
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00         7
#            8       1.00      1.00      1.00        16
#            9       0.98      1.00      0.99        40
#           10       1.00      0.33      0.50         3
#           11       0.00      0.00      0.00         2
#           12       0.86      0.97      0.91        32
#           13       0.86      1.00      0.92         6
#           14       1.00      0.25      0.40         4
#           15       1.00      0.50      0.67         6
#           16       1.00      1.00      1.00         4
#           17       1.00      0.83      0.91        30
#           18       0.00      0.00      0.00         1
#           19       0.97      0.82      0.89        40
#           20       1.00      0.75      0.86         8
#           21       1.00      0.92      0.96        12
#           22       1.00      0.93      0.96        14
#           23       0.92      0.89      0.90        79
#           24       1.00      1.00      1.00         9
#           34       0.96      0.88      0.92        25
#           35       0.00      0.00      0.00         0
#           45       0.85      0.89      0.87        64
#           50       0.00      0.00      0.00         0
#           54       0.80      1.00      0.89        20
#           55       1.00      0.82      0.90        50
#           56       1.00      1.00      1.00         3
#           57       0.00      0.00      0.00         1
#
#     accuracy                           0.90       616
#    macro avg       0.81      0.74      0.75       616
# weighted avg       0.94      0.90      0.91       616
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(val_generator.classes, predictions.argmax(axis=1))
plt.figure(figsize=(20,20))
sns.heatmap(cm,  annot=True, fmt="d" ,cmap="YlGnBu")
# Out:
# <Axes: >
